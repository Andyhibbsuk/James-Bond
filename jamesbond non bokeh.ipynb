# %%
import pandas as pd
import numpy as np

# %%
jamesb=pd.read_csv("jamesbond.csv")

# %%
jamesb.describe()
# Out:
#               Year  Box Office      Budget  Bond Actor Salary
# count    26.000000   26.000000   26.000000          18.000000
# mean   1983.576923  491.611538   80.719231           6.850000
# std      16.295209  176.740396   57.097608           4.805175
# min    1962.000000  250.900000    7.000000           0.600000
# 25%    1969.500000  375.350000   38.450000           3.575000
# 50%    1982.000000  461.750000   60.050000           5.500000
# 75%    1996.500000  534.500000  123.300000           8.850000
# max    2015.000000  943.500000  206.300000          17.900000

# %%
actbox=jamesb[["Actor","Box Office"]]
actsal=jamesb[["Actor","Bond Actor Salary"]]
countperacsal=jamesb.groupby(["Actor"],as_index=False)["Bond Actor Salary"].agg("sum")

countperac=actbox.groupby(["Actor"],as_index=False)["Box Office"].agg("sum")
countperac["Total Salary"]=countperacsal[["Bond Actor Salary"]]
countperac.sort_values("Total Salary",inplace=True)
countperac.plot.bar(y=["Box Office","Total Salary"],x="Actor",subplots=True,figsize=(8,8))
# Out:
# array([<AxesSubplot:title={'center':'Box Office'}, xlabel='Actor'>,
#        <AxesSubplot:title={'center':'Total Salary'}, xlabel='Actor'>],
#       dtype=object)

# %%
jamesbyearplot.plot.line(x="Year",y=["Box Office","Budget"])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
countperac
# Out:
#             Actor  Box Office  Total Salary
# 1     David Niven       315.0           0.0
# 2  George Lazenby       291.5           0.6
# 6  Timothy Dalton       564.4          13.1
# 4     Roger Moore      2960.7          16.9
# 5    Sean Connery      3997.8          20.3
# 0    Daniel Craig      2765.9          25.9
# 3  Pierce Brosnan      1886.6          46.5

# %%
jamesb
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jamesb["Budget"].min()
# Out:
# 7.0

# %%
jamesb["Rank"]=jamesb["Box Office"].rank(ascending=False)

# %%
jamesb=jamesb.sort_values("Rank")

# %%
jamesb
# Out:
#                                Film  Year           Actor            Director  \
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# ...

# %%
jamesb["Actor"].value_counts()
# Out:
# Sean Connery      7
# Roger Moore       7
# Daniel Craig      4
# Pierce Brosnan    4
# Timothy Dalton    2
# David Niven       1
# George Lazenby    1
# Name: Actor, dtype: int64

# %%
jamesb["Year"].value_counts()
# Out:
# 1983    2
# 1967    2
# 2012    1
# 1973    1
# 1985    1
# 1969    1
# 1987    1
# 1974    1
# 1999    1
# 1971    1
# 1962    1
# 1981    1
# 1997    1
# 1965    1
# 2002    1
# 2008    1
# 1995    1
# 1977    1
# 1979    1
# 1963    1
# 2006    1
# 2015    1
# 1964    1
# 1989    1
# Name: Year, dtype: int64

# %%
jamesbyearplot.plot.line(x="Year",y=["Box Office","Budget"])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
jamesbyearplot.dtypes
# Out:
# Film                  object
# Year                   int64
# Actor                 object
# Director              object
# Box Office           float64
# Budget               float64
# Bond Actor Salary    float64
# Rank                 float64
# Budget/Box Office    float64
# dtype: object
